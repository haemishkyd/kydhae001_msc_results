# %%
import glob
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import numpy as np

files = glob.glob("output_folderDICe*.txt")
final_list = sorted(files)
all_displacements = []
z_displacements = []
y_displacements = []
x_displacements = []

for file_name in final_list:
    data = pd.read_csv(file_name)
    all_displacements.append(data)
    z_displacements.append(data.MODEL_DISPLACEMENT_Z)
    y_displacements.append(data.MODEL_DISPLACEMENT_Y)
    x_displacements.append(data.MODEL_DISPLACEMENT_X)

data_1 = pd.read_csv("timing.txt")
execution_speed_1 = data_1["Entire Process"]
sample_rate = np.average(execution_speed_1)
x_data=np.arange(0,len(z_displacements[0])*sample_rate,sample_rate)
print(x_data)
# Out:
# [ 0.          1.44599585  2.8919917   4.33798755  5.7839834   7.22997925
#   8.67597509 10.12197094 11.56796679 13.01396264 14.45995849 15.90595434
#  17.35195019 18.79794604 20.24394189 21.68993774 23.13593358 24.58192943
#  26.02792528 27.47392113 28.91991698 30.36591283 31.81190868 33.25790453
#  34.70390038 36.14989623 37.59589208 39.04188792 40.48788377 41.93387962
#  43.37987547 44.82587132 46.27186717 47.71786302 49.16385887 50.60985472
#  52.05585057 53.50184642 54.94784226 56.39383811 57.83983396 59.28582981
#  60.73182566 62.17782151 63.62381736 65.06981321 66.51580906 67.96180491
#  69.40780075 70.8537966  72.29979245 73.7457883 ]

# %%
plt.rcParams['figure.figsize'] = [40/2.54, 32/2.54]
plt.title("Z Displacement",fontsize = 30)
plt.ylabel("Displacement (mm)")
plt.xlabel("Time (s)")
plt.grid()
plt.plot(x_data,z_displacements[0])
for disp in z_displacements[:94]:
    plt.plot(x_data,disp,'o')

# %%
print(z_displacements[0][10:20])
# Out:
# 10   -0.000995
# 11    0.000480
# 12    0.006295
# 13    0.015573
# 14    0.002805
# 15    0.393450
# 16    1.219100
# 17    1.929100
# 18    2.778100
# 19    3.467800
# Name: MODEL_DISPLACEMENT_Z, dtype: float64

# %%
print(z_displacements[0][40:50])
# Out:
# 40    0.875150
# 41    0.120120
# 42    0.085281
# 43    0.090948
# 44    0.079027
# 45    0.090355
# 46    0.074147
# 47    0.090088
# 48    0.090769
# 49    0.088887
# Name: MODEL_DISPLACEMENT_Z, dtype: float64

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import numpy as np
# Out:
# 1.4459958490566036
