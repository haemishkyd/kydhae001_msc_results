# %%
import glob
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import numpy as np

files = glob.glob("output_folderDICe*.txt")
final_list = sorted(files)
all_displacements = []
z_displacements = []
y_displacements = []
x_displacements = []

for file_name in final_list:
    data = pd.read_csv(file_name)
    all_displacements.append(data)
    z_displacements.append(data.MODEL_DISPLACEMENT_Z)
    y_displacements.append(data.MODEL_DISPLACEMENT_Y)
    x_displacements.append(data.MODEL_DISPLACEMENT_X)

data_1 = pd.read_csv("timing.txt")
execution_speed_1 = data_1["Entire Process"]
sample_rate = np.average(execution_speed_1)
x_data=np.arange(0,len(z_displacements[0])*sample_rate,sample_rate)
print(x_data)
# Out:
# [ 0.          1.4147066   2.82941321  4.24411981  5.65882642  7.07353302
#   8.48823962  9.90294623 11.31765283 12.73235943 14.14706604 15.56177264
#  16.97647925 18.39118585 19.80589245 21.22059906 22.63530566 24.05001226
#  25.46471887 26.87942547 28.29413208 29.70883868 31.12354528 32.53825189
#  33.95295849 35.36766509 36.7823717  38.1970783  39.61178491 41.02649151
#  42.44119811 43.85590472 45.27061132 46.68531792 48.10002453 49.51473113
#  50.92943774 52.34414434 53.75885094 55.17355755 56.58826415 58.00297075
#  59.41767736 60.83238396 62.24709057 63.66179717 65.07650377 66.49121038
#  67.90591698 69.32062358 70.73533019 72.15003679]

# %%
plt.rcParams['figure.figsize'] = [40/2.54, 32/2.54]
plt.title("Z Displacement",fontsize = 30)
plt.ylabel("Displacement (mm)")
plt.xlabel("Time (s)")
plt.grid()
plt.plot(x_data,z_displacements[0])
for disp in z_displacements[:94]:
    plt.plot(x_data,disp,'o')

# %%
print (z_displacements[0][5:20])
# Out:
# 5     -0.010740
# 6     -0.010430
# 7     -0.011349
# 8     -0.004576
# 9     -0.007818
# 10    10.559000
# 11    10.640000
# 12    10.634000
# 13    10.630000
# 14    10.627000
# 15    10.621000
# 16    10.641000
# 17    10.626000
# 18    -0.018932
# 19    -0.022016
# Name: MODEL_DISPLACEMENT_Z, dtype: float64
