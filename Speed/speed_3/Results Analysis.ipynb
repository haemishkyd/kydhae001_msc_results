# %%
import glob
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import numpy as np

files = glob.glob("output_folderDICe*.txt")
final_list = sorted(files)
all_displacements = []
z_displacements = []
y_displacements = []
x_displacements = []

for file_name in final_list:
    data = pd.read_csv(file_name)
    all_displacements.append(data)
    z_displacements.append(data.MODEL_DISPLACEMENT_Z)
    y_displacements.append(data.MODEL_DISPLACEMENT_Y)
    x_displacements.append(data.MODEL_DISPLACEMENT_X)
data_1 = pd.read_csv("timing.txt")
execution_speed_1 = data_1["Entire Process"]
sample_rate = np.average(execution_speed_1)
x_data=np.arange(0,len(z_displacements[0])*sample_rate,sample_rate)
print(x_data)
# Out:
# [ 0.          1.41003483  2.82006967  4.2301045   5.64013933  7.05017417
#   8.460209    9.87024383 11.28027867 12.6903135  14.10034833 15.51038317
#  16.920418   18.33045283 19.74048767 21.1505225  22.56055733 23.97059217
#  25.380627   26.79066183 28.20069667 29.6107315  31.02076633 32.43080117
#  33.840836   35.25087083 36.66090567 38.0709405  39.48097533 40.89101017
#  42.301045   43.71107983 45.12111467 46.5311495  47.94118433 49.35121917
#  50.761254   52.17128883 53.58132367 54.9913585  56.40139333 57.81142817
#  59.221463   60.63149783 62.04153267 63.4515675  64.86160233 66.27163717
#  67.681672   69.09170683 70.50174167 71.9117765  73.32181133 74.73184617
#  76.141881   77.55191583 78.96195067 80.3719855  81.78202033]

# %%
plt.rcParams['figure.figsize'] = [40/2.54, 32/2.54]
plt.title("Z Displacement",fontsize = 30)
plt.ylabel("Displacement (mm)")
plt.xlabel("Time (s)")
plt.grid()
plt.plot(x_data,z_displacements[0])
for disp in z_displacements[:94]:
    plt.plot(x_data,disp,'o')

# %%
print (z_displacements[0][10:25])
# Out:
# 10     0.035046
# 11     0.021937
# 12     5.904800
# 13    10.667000
# 14    10.670000
# 15    10.672000
# 16    10.673000
# 17    10.686000
# 18    10.672000
# 19    10.661000
# 20     3.943600
# 21     0.034471
# 22     0.030876
# 23     0.025018
# 24     0.023894
# Name: MODEL_DISPLACEMENT_Z, dtype: float64
